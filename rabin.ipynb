# %% [markdown]
# # ***Cristiano Ronaldo dos Santos Aveiro, commonly known as Cristiano Ronaldo, is a Portuguese professional football player who is widely regarded as one of the greatest players of all time. He was born on February 5, 1985, in Funchal, Madeira, Portugal.
# #
# # Ronaldo began his football career playing for Andorinha and Nacional youth teams before joining the Sporting CP Academy at the age of 12. He made his professional debut for Sporting CP in 2002 and was signed by Manchester United in 2003, where he spent six successful seasons, winning three Premier League titles, one FA Cup, one UEFA Champions League title, and one FIFA Club World Cup.
# #
# # In 2009, Ronaldo moved to Real Madrid for a then world-record transfer fee of €94 million. He spent nine seasons at the club, scoring 450 goals in 438 appearances, and winning four UEFA Champions League titles, two La Liga titles, and two Copa del Rey titles. In 2018, Ronaldo signed for Juventus, where he currently plays.
# #
# # Ronaldo has also had a highly successful international career with the Portugal national team, scoring 115 goals in 189 appearances. He helped Portugal win the UEFA European Championship in 2016 and the UEFA Nations League in 2019.
# #
# # Throughout his career, Ronaldo has won numerous individual awards, including five Ballon d'Or awards, which are given to the best player in the world. He is known for his incredible speed, strength, and goal-scoring ability, as well as his dedication to training and his highly competitive nature.*******

# %% [markdown]
# # **This will import Pandas, Seaborn, and Matplotlib and allow you to use their functions and methods in your Python code**

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
from datetime import timedelta
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')#The warnings.filterwarnings('ignore') line is used to suppress warning messages 
#that may be generated by the code
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # **Importing dataset**

# %%
data=pd.read_csv('/kaggle/input/data-7/data.csv')
data
# Out:
#     Season               Competition      Matchday      Date Venue  \
# 0    02/03             Liga Portugal             6  10-07-02     H
# 1    02/03             Liga Portugal             6  10-07-02     H
# 2    02/03             Liga Portugal             8  10/26/02     A
# 3    02/03  Taca de Portugal Placard  Fourth Round  11/24/02     H
# 4    02/03  Taca de Portugal Placard   Fifth Round  12/18/02     H
# ..     ...                       ...           ...       ...   ...
# 696  21/22            Premier League            37   4/28/22     H
# 697  21/22            Premier League            35  05-02-22     H
# 698  22/23             Europa League   Group Stage   9/15/22     A
# 699  22/23            Premier League            10   10/9/22     A
# 700  22/23             Europa League   Group Stage  10/27/22     H
#
#                   Club                 Opponent Result Playing_Position  \
# 0          Sporting CP            Moreirense FC   3:00               LW
# ...

# %% [markdown]
# # **Checking whether there are duplicate values**

# %%
duplicate_data=data.duplicated().any()
print("There are any duplicate value ",duplicate_data)
# Out:
# There are any duplicate value  False

# %%
data.head(10)
# Out:
#   Season               Competition      Matchday      Date Venue  \
# 0  02/03             Liga Portugal             6  10-07-02     H
# 1  02/03             Liga Portugal             6  10-07-02     H
# 2  02/03             Liga Portugal             8  10/26/02     A
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02     H
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02     H
# 5  03/04            Premier League            11  11-01-03     H
# 6  03/04                    FA Cup   Fifth Round   2/14/04     H
# 7  03/04            Premier League            29   3/20/04     H
# 8  03/04            Premier League            32  04-10-04     A
# 9  03/04            Premier League            38   5/15/04     A
#
#                 Club                 Opponent Result Playing_Position Minute  \
# 0        Sporting CP            Moreirense FC   3:00               LW     34
# 1        Sporting CP            Moreirense FC   3:00               LW   90+5
# ...

# %%
data.describe(include="all")
# Out:
#        Season Competition     Matchday      Date Venue         Club  \
# count     701         701          701       701   701          701
# unique     21          16           52       464     2            4
# top     14/15      LaLiga  Group Stage  09-12-15     H  Real Madrid
# freq       61         311           75         5   403          450
#
#           Opponent Result Playing_Position Minute At_score               Type  \
# count          701    701              643    701      701                686
# unique         125     53                5    106       37                 11
# top     Sevilla FC   3:00               LW     90     1:00  Right-footed shot
# freq            27     49              356     17      111                251
#
#           Goal_assist
# count             459
# unique             86
# top     Karim Benzema
# freq               44

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            701 non-null    object
#  1   Competition       701 non-null    object
#  2   Matchday          701 non-null    object
#  3   Date              701 non-null    object
#  4   Venue             701 non-null    object
#  5   Club              701 non-null    object
#  6   Opponent          701 non-null    object
#  7   Result            701 non-null    object
#  8   Playing_Position  643 non-null    object
#  9   Minute            701 non-null    object
#  10  At_score          701 non-null    object
#  11  Type              686 non-null    object
#  12  Goal_assist       459 non-null    object
# dtypes: object(13)
# memory usage: 71.3+ KB

# %% [markdown]
# # **changing the style of pandas dataframe**

# %%
data.head(25).style.set_table_styles(
[{'selector': 'th',  'props': [('background', '#7CAE00'),             ('color', 'white'),            ('font-family', 'verdana')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'grey'),
            ('cursor', 'pointer')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'yellow'),
            ('cursor', 'pointer')]},
 
]
 ).hide_index()
# Out:
# <style type="text/css">
# #T_e9fcb_ th {
#   background: #7CAE00;
#   color: white;
#   font-family: verdana;
# }
# #T_e9fcb_ td {
#   font-family: verdana;
# }
# #T_e9fcb_ tr:nth-of-type(odd) {
#   background: grey;
#   cursor: pointer;
# }
# #T_e9fcb_ tr:nth-of-type(even) {
#   background: yellow;
#   cursor: pointer;
# }
# </style>
# <table id="T_e9fcb_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Season</th>
#       <th class="col_heading level0 col1" >Competition</th>
#       <th class="col_heading level0 col2" >Matchday</th>
#       <th class="col_heading level0 col3" >Date</th>
#       <th class="col_heading level0 col4" >Venue</th>
#       <th class="col_heading level0 col5" >Club</th>
#       <th class="col_heading level0 col6" >Opponent</th>
#       <th class="col_heading level0 col7" >Result</th>
#       <th class="col_heading level0 col8" >Playing_Position</th>
#       <th class="col_heading level0 col9" >Minute</th>
# ...

# %% [markdown]
# # **groupby() method to group a DataFrame**

# %%
x=data.groupby("Club")
x

# %%
for Club,Club_data in x:
    print(Club)
    print(Club_data)
# Out:
# Juventus FC
#     Season Competition Matchday      Date Venue         Club  \
# 573  18/19     Serie A        4   9/16/18     H  Juventus FC
# 574  18/19     Serie A        4   9/16/18     H  Juventus FC
# 575  18/19     Serie A        5   9/23/18     A  Juventus FC
# 576  18/19     Serie A        8  10-06-18     A  Juventus FC
# 577  18/19     Serie A        9  10/20/18     H  Juventus FC
# ..     ...         ...      ...       ...   ...          ...
# 669  20/21     Serie A        3  04-07-21     H  Juventus FC
# 670  20/21     Serie A       34  05-02-21     A  Juventus FC
# 671  20/21     Serie A       34  05-02-21     A  Juventus FC
# 672  20/21     Serie A       36  05-12-21     A  Juventus FC
# 673  20/21     Serie A       37   5/15/21     H  Juventus FC
#
#              Opponent Result Playing_Position Minute At_score  \
# 573       US Sassuolo   2:01               CF     50     1:00
# 574       US Sassuolo   2:01               CF     65     2:00
# ...

# %%
x.get_group("Juventus FC")
# Out:
#     Season Competition Matchday      Date Venue         Club  \
# 573  18/19     Serie A        4   9/16/18     H  Juventus FC
# 574  18/19     Serie A        4   9/16/18     H  Juventus FC
# 575  18/19     Serie A        5   9/23/18     A  Juventus FC
# 576  18/19     Serie A        8  10-06-18     A  Juventus FC
# 577  18/19     Serie A        9  10/20/18     H  Juventus FC
# ..     ...         ...      ...       ...   ...          ...
# 669  20/21     Serie A        3  04-07-21     H  Juventus FC
# 670  20/21     Serie A       34  05-02-21     A  Juventus FC
# 671  20/21     Serie A       34  05-02-21     A  Juventus FC
# 672  20/21     Serie A       36  05-12-21     A  Juventus FC
# 673  20/21     Serie A       37   5/15/21     H  Juventus FC
#
#              Opponent Result Playing_Position Minute At_score  \
# 573       US Sassuolo   2:01               CF     50     1:00
# 574       US Sassuolo   2:01               CF     65     2:00
# ...

# %%
x.get_group("Juventus FC").max()
# Out:
# Season                              20/21
# Competition         UEFA Champions League
# Matchday                          last 16
# Date                              9/28/19
# Venue                                   H
# Club                          Juventus FC
# Opponent                   Udinese Calcio
# Result                               4:03
# Playing_Position                       LW
# Minute                               90+6
# At_score                             4:00
# Type                               Tap-in
# dtype: object

# %%
x.get_group("Manchester United")
# Out:
#     Season     Competition     Matchday      Date Venue               Club  \
# 5    03/04  Premier League           11  11-01-03     H  Manchester United
# 6    03/04          FA Cup  Fifth Round   2/14/04     H  Manchester United
# 7    03/04  Premier League           29   3/20/04     H  Manchester United
# 8    03/04  Premier League           32  04-10-04     A  Manchester United
# 9    03/04  Premier League           38   5/15/04     A  Manchester United
# ..     ...             ...          ...       ...   ...                ...
# 696  21/22  Premier League           37   4/28/22     H  Manchester United
# 697  21/22  Premier League           35  05-02-22     H  Manchester United
# 698  22/23   Europa League  Group Stage   9/15/22     A  Manchester United
# 699  22/23  Premier League           10   10/9/22     A  Manchester United
# 700  22/23   Europa League  Group Stage  10/27/22     H  Manchester United
#
#               Opponent Result Playing_Position Minute At_score  \
# ...

# %%
x.get_group("Manchester United").max()
# Out:
# Season                                    22/23
# Competition    UEFA Champions League Qualifying
# Matchday                                last 16
# Date                                    9/29/21
# Venue                                         H
# Club                          Manchester United
# Opponent                         Wigan Athletic
# Result                                     7:01
# Minute                                     90+5
# At_score                                   5:00
# dtype: object

# %%
x.get_group("Real Madrid")
# Out:
#     Season            Competition        Matchday      Date Venue  \
# 123  09/10                 LaLiga               1   8/29/09     H
# 124  09/10                 LaLiga               2  09-12-09     A
# 125  09/10  UEFA Champions League     Group Stage   9/15/09     A
# 126  09/10  UEFA Champions League     Group Stage   9/15/09     A
# 127  09/10                 LaLiga               3   9/20/09     H
# ..     ...                    ...             ...       ...   ...
# 568  17/18                 LaLiga              31  04-08-18     H
# 569  17/18  UEFA Champions League  Quarter-Finals  04-11-18     H
# 570  17/18                 LaLiga              33   4/18/18     H
# 571  17/18                 LaLiga              36  05-06-18     A
# 572  17/18                 LaLiga              38   5/19/18     A
#
#             Club                 Opponent Result Playing_Position Minute  \
# 123  Real Madrid  Deportivo de La CoruÃ±a   3:02               RW     35
# ...

# %%
x.get_group("Real Madrid").max()
# Out:
# Season                 Dec-13
# Competition    UEFA Super Cup
# Matchday              last 16
# Date                  9/30/15
# Venue                       H
# Club              Real Madrid
# Opponent             Xerez CD
# Result                   9:01
# Minute                     97
# At_score                 9:01
# Type                   Tap-in
# dtype: object

# %%
x.max()
# Out:
#                    Season                       Competition      Matchday  \
# Club
# Juventus FC         20/21             UEFA Champions League       last 16
# Manchester United   22/23  UEFA Champions League Qualifying       last 16
# Real Madrid        Dec-13                    UEFA Super Cup       last 16
# Sporting CP         02/03          Taca de Portugal Placard  Fourth Round
#
#                        Date Venue        Opponent Result Minute At_score
# Club
# Juventus FC         9/28/19     H  Udinese Calcio   4:03   90+6     4:00
# Manchester United   9/29/21     H  Wigan Athletic   7:01   90+5     5:00
# Real Madrid         9/30/15     H        Xerez CD   9:01     97     9:01
# Sporting CP        12/18/02     H   Moreirense FC   8:01   90+5     3:00

# %%
x.min()
# Out:
#                   Season    Competition Matchday      Date Venue     Opponent  \
# Club
# Juventus FC        18/19      Italy Cup        1  01-03-21     A     AC Milan
# Manchester United  03/04        EFL Cup        1  01-05-08     A     AC Milan
# Real Madrid        09/10   Copa del Rey        1  01-03-11     A     AC Milan
# Sporting CP        02/03  Liga Portugal        6  10-07-02     A  Boavista FC
#
#                   Result Minute At_score
# Club
# Juventus FC         0:01     10     0:01
# Manchester United   0:01     10     0:01
# Real Madrid         0:01      1     0:01
# Sporting CP         1:02     13     1:02

# %% [markdown]
# **Goals per competition**

# %% [markdown]
# # **Goals per competition**

# %%
px.histogram(
    data,
    x='Competition',
    title="Goals per competition",
    log_x=False,#log_x, is set to True, the x-axis will be displayed on a logarithmic scale
    log_y=False,#log_y,is set to True, the x-axis will be displayed on a logarithmic scale
   
    height=600,
    color='Club',
    hover_name='Club',
    hover_data=['Competition','Season','Club'])
#Instead of this code we use this one but comparing to histogram ,histrogram is better in visual
#plot = sns.countplot(x="Competition", data=data)
#plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
#plt.show()
# Out:
# <div>                            <div id="2037bf38-edce-426d-859a-16eb204f1548" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2037bf38-edce-426d-859a-16eb204f1548")) {                    Plotly.newPlot(                        "2037bf38-edce-426d-859a-16eb204f1548",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Club=Sporting CP<br>Competition=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Sporting CP","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sporting CP","offsetgroup":"Sporting CP","orientation":"v","showlegend":true,"x":["Liga Portugal","Liga Portugal","Liga Portugal","Taca de Portugal Placard","Taca de Portugal Placard"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","
# ...

# %%
[data.Competition.value_counts()]
# Out:
# [LaLiga                              311
#  UEFA Champions League               140
#  Premier League                      103
#  Serie A                              81
#  Copa del Rey                         22
#  FA Cup                               13
#  FIFA Club World Cup                   7
#  EFL Cup                               4
#  Supercopa                             4
#  Italy Cup                             4
#  Liga Portugal                         3
#  Taca de Portugal Placard              2
#  UEFA Super Cup                        2
#  Supercoppa Italiana                   2
#  Europa League                         2
#  UEFA Champions League Qualifying      1
#  Name: Competition, dtype: int64]

# %% [markdown]
# # **Goals per Clubs**

# %%
px.histogram(
    data,
    x='Club',
    title="Goals per Clubs - Seasons",
    log_x=False,#by default it is set as False
    log_y=False, 
    height=600,
    color='Season',
    hover_name='Season',
    hover_data=['Competition','Season','Club'])
# Out:
# <div>                            <div id="90dfe22a-47ac-4887-9858-c649c2f1fdd1" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90dfe22a-47ac-4887-9858-c649c2f1fdd1")) {                    Plotly.newPlot(                        "90dfe22a-47ac-4887-9858-c649c2f1fdd1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Season=02/03<br>Club=%{x}<br>count=%{y}<extra></extra>","legendgroup":"02/03","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"02/03","offsetgroup":"02/03","orientation":"v","showlegend":true,"x":["Sporting CP","Sporting CP","Sporting CP","Sporting CP","Sporting CP"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Season=03/04<br>Club=%{x}<br>c
# ...

# %%
data.Club.value_counts()
# Out:
# Real Madrid          450
# Manchester United    145
# Juventus FC          101
# Sporting CP            5
# Name: Club, dtype: int64

# %% [markdown]
# # Goals per Clubs in competition

# %%
px.histogram(
    data,
    x='Club',
    title="Goals per Clubs - Competition",
    log_x=False,
    log_y=False, 
    height=600,
    color='Competition',
    hover_name='Competition',
    hover_data=['Competition','Season','Club'])
# Out:
# <div>                            <div id="67ee563c-6366-4fd5-9362-6cb273592dc1" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67ee563c-6366-4fd5-9362-6cb273592dc1")) {                    Plotly.newPlot(                        "67ee563c-6366-4fd5-9362-6cb273592dc1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Competition=Liga Portugal<br>Club=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Liga Portugal","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Liga Portugal","offsetgroup":"Liga Portugal","orientation":"v","showlegend":true,"x":["Sporting CP","Sporting CP","Sporting CP"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Competition=Taca de P
# ...

# %%
data.Competition.value_counts()
# Out:
# LaLiga                              311
# UEFA Champions League               140
# Premier League                      103
# Serie A                              81
# Copa del Rey                         22
# FA Cup                               13
# FIFA Club World Cup                   7
# EFL Cup                               4
# Supercopa                             4
# Italy Cup                             4
# Liga Portugal                         3
# Taca de Portugal Placard              2
# UEFA Super Cup                        2
# Supercoppa Italiana                   2
# Europa League                         2
# UEFA Champions League Qualifying      1
# Name: Competition, dtype: int64

# %% [markdown]
# #  Goal per Season

# %%
px.histogram(
    data,
    x='Season',
    title="Goals per season",
    log_x=False,
    log_y=False,
     
    height=600,
    color='Club',
    hover_name='Club',
    hover_data=['Competition','Season','Club'])
# Out:
# <div>                            <div id="fa7b8005-62ff-4f69-bb6d-bc401f4bab50" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa7b8005-62ff-4f69-bb6d-bc401f4bab50")) {                    Plotly.newPlot(                        "fa7b8005-62ff-4f69-bb6d-bc401f4bab50",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Club=Sporting CP<br>Season=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Sporting CP","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sporting CP","offsetgroup":"Sporting CP","orientation":"v","showlegend":true,"x":["02/03","02/03","02/03","02/03","02/03"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Club=Manchester United<br>Season=%{x
# ...

# %%
data.Season.value_counts()
# Out:
# 14/15     61
# 11/12     60
# Dec-13    55
# 10/11     53
# 13/14     51
# 15/16     51
# 17/18     44
# 07/08     42
# 16/17     42
# 19/20     37
# 20/21     36
# 09/10     33
# 18/19     28
# 08/09     26
# 21/22     24
# 06/07     23
# 05/06     12
# 04/05      9
# 03/04      6
# 02/03      5
# 22/23      3
# Name: Season, dtype: int64

# %% [markdown]
# # Goals Per playing position

# %%
px.histogram(
    data,
    x='Playing_Position',
    title="Goals per playing Position",
    log_x=False,
    log_y=False,
    height=500,
    color='Club',
    hover_name='Club',
    hover_data=['Playing_Position','Competition','Season','Club'])
# Out:
# <div>                            <div id="4dd0af40-8158-427b-ab9a-d368f7b1ce13" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dd0af40-8158-427b-ab9a-d368f7b1ce13")) {                    Plotly.newPlot(                        "4dd0af40-8158-427b-ab9a-d368f7b1ce13",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Club=Sporting CP<br>Playing_Position=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Sporting CP","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sporting CP","offsetgroup":"Sporting CP","orientation":"v","showlegend":true,"x":["LW","LW",null,null,null],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Club=Manchester United<br>Playing_Positio
# ...

# %%
data.Playing_Position.value_counts()
# Out:
# LW     356
# CF     200
# RW      79
# LW       5
# CF       3
# Name: Playing_Position, dtype: int64

# %% [markdown]
# # Type of goals

# %%
px.histogram(
    data,
    x='Type',
    title="Goals per Type",
    log_x=False,
    log_y=False,
    height=500,
    color='Club',
    hover_name='Club',
    hover_data=['Playing_Position','Competition','Season','Club'])
# Out:
# <div>                            <div id="04e5afa7-43e2-489c-9c3e-ce2d7eb896fb" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04e5afa7-43e2-489c-9c3e-ce2d7eb896fb")) {                    Plotly.newPlot(                        "04e5afa7-43e2-489c-9c3e-ce2d7eb896fb",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Club=Sporting CP<br>Type=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Sporting CP","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sporting CP","offsetgroup":"Sporting CP","orientation":"v","showlegend":true,"x":["Solo run","Header","Right-footed shot","Left-footed shot",null],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Club=Mancheste
# ...

# %% [markdown]
# # BASED ON TIME

# %%
mins=list(map(str, range(1,121)))#Creates a list of strings representing minutes from 1 to 120 using the range() function and the map() function to convert each integer to a string
mins.insert(45,"1stE")
mins.insert(91,"2ndE")
mins.insert(122,"extra")
data.loc[data.Minute.str[:3]=='45+', 'Minute'] = '1stE'
data.loc[data.Minute.str[:3]=='90+', 'Minute'] = '2ndE'
data.loc[data.Minute.str[:4]=='120+', 'Minute'] = 'Extra'
mins1=mins[:23]
mins2=mins[23:46]
mins3=mins[46:69]
mins4=mins[69:92]
mins5=mins[92:]

# %%
sns.set(rc={'figure.figsize':(20,7)})
plt.xticks(fontsize=20)
p=sns.countplot(x='Minute',data=data,order=mins1)
p.axes.set_title("Goals per Game Minute (1-23)",fontsize=35)
# Out:
# Text(0.5, 1.0, 'Goals per Game Minute (1-23)')

# %%
p=sns.countplot(x='Minute',data=data,order=mins2)
p.axes.set_title("Goals per Game Minute (24-First Half Extra time)",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Goals per Game Minute (24-First Half Extra time)')

# %%
p=sns.countplot(x='Minute',data=data,order=mins3)
p.axes.set_title("Goals per Game Minute (46-68)",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Goals per Game Minute (46-68)')

# %%
p=sns.countplot(x='Minute',data=data,order=mins4)
p.axes.set_title("Goals per Game Minute 69- 2nd Half Extra time)",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Goals per Game Minute 69- 2nd Half Extra time)')

# %%
p=sns.countplot(x='Minute',data=data,order=mins5)
p.axes.set_title("Goals per Game Minute (91-Extra times)",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Goals per Game Minute (91-Extra times)')

# %% [markdown]
# # Score After Goals

# %%
sns.set(rc={'figure.figsize':(20,5)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(x='At_score',data=data)
p.axes.set_title("Scoresheet after scoring",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Scoresheet after scoring')

# %% [markdown]
# # opponent

# %%
sns.set(rc={'figure.figsize':(10,5)})
opponents_df=data.groupby('Opponent').size().reset_index(name='count')
fav_opponents_df=opponents_df[opponents_df["count"]>15]
plt.xticks(fontsize=20,rotation='vertical')
plt.bar(x=fav_opponents_df['Opponent'],height=fav_opponents_df['count'],color="black")
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# # Goals per opponent

# %%
mins=list(map(str, data.Opponent.value_counts().sort_values(ascending=False).index))
for min in data['Opponent']:
    if min not in mins:
        mins.append(min)
mins1=mins[:int(len(mins)/5)]
mins2=mins[int(len(mins)/5):int(2*len(mins)/5)]
mins3=mins[2*int(len(mins)/5):int(3*len(mins)/5)]
mins4=mins[3*int(len(mins)/5):int(4*len(mins)/5)]
mins5=mins[int(4*len(mins)/5):]

# %%
sns.set(rc={'figure.figsize':(20,5)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(x='Opponent',data=data,order=mins1)
p.axes.set_title("Goals per Opponents",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Goals per Opponents')

# %%
sns.set(rc={'figure.figsize':(20,5)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(x='Opponent',data=data,order=mins2)
p.axes.set_title("Goals per Opponents",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Goals per Opponents')

# %%
sns.set(rc={'figure.figsize':(20,5)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(x='Opponent',data=data,order=mins3)
p.axes.set_title("Goals per Opponents",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Goals per Opponents')

# %%
sns.set(rc={'figure.figsize':(20,5)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(x='Opponent',data=data,order=mins4)
p.axes.set_title("Goals per Opponents",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Goals per Opponents')
